# %%
a=5
print(a)
# Out:
# 5

# %%
a=5
print(a)
a="anu"
print(a)
# Out:
# 5
# anu

# %%
name="anu"
print(name)
Name="anusha"
print(Name)
NAME="anushaanu"
print(NAME)
# Out:
# anu
# anusha
# anushaanu

# %%
print("hello world")
# Out:
# hello world

# %%
a="python language"
print(a)
# Out:
# python language

# %%
first_name="Anusha"
last_name="ranga"
print(first_name)
print(last_name)
# Out:
# Anusha
# ranga

# %%
print(first_name, end="-")
print(last_name)
# Out:
# Anusha-ranga

# %%
name="python"
print("I am learning "+name)
# Out:
# I am learning python

# %%
name1="language"
print("i am learning "+name+name1)
# Out:
# i am learning pythonlanguage

# %%
#print format
fruit='apple'
fruit1='banana'
print(" I have 2 fruits, one is {} other one is {}".format(fruit,fruit1))
# Out:
#  I have 2 fruits, one is apple other one is banana

# %%
#Giving indexes
print(" I have 2 fruits, one is {1} other one is {0}".format(fruit,fruit1))
# Out:
#  I have 2 fruits, one is banana other one is apple

# %% [markdown]
# comments examples

# %%
#This is a comment
print('hello world')
# Out:
# hello world

# %%
print('hello world') #we can write comment here too
# Out:
# hello world

# %%
print('hello')
#we can write comments in middle of the code
print('world')
# Out:
# hello
# world

# %%
#i am
#a multiline
#comment
#every line should start with '#'
print('hello world')
# Out:
# hello world

# %% [markdown]
# there is another way to use multiline comments by using """..."""

# %%
"""
this is
another way
of using multiline
comments
"""
print('hello world')
# Out:
# hello world

# %% [markdown]
# input() function is used to take input from the console that means user desired output

# %%
name= input("Enter your name : ")
print("my name is "+name)
# Out:
# Enter your name : Anusha
# my name is Anusha

# %%
name = input("enter the first name : ")
name1 = input("enter the second name : ")
name2 = name + name1 
print(name2)
# Out:
# AnushaRanga

# %%
num1 = input("enter the first number : ")
num2 = input("enter the second number : ")
num3 = num1 + num2 
print(num3)
# Out:
# enter the first number : 5
# enter the second number : 3
# 53

# %%
print("type of num1 = {} and num2 = {} ".format(type(num1),type(num2)))
# Out:
# type of num1 = <class 'str'> and num2 = <class 'str'>

# %%
num1 = int(num1) #converting to int
num2 = int(num2)
num3 = num1 + num2 
print(num3)
# Out:
# 8
